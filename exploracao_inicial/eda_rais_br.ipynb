# %%
import pandas as pd

# %%
df_rais = pd.read_csv("./data/RAIS_ESTAB_PUB.txt", sep=";", encoding="latin1")

# %%
df_rais.head()
# Out:
#    Bairros SP  Bairros Fortaleza  Bairros RJ  CNAE 2.0 Classe  CNAE 95 Classe  \
# 0        9997               9997        9997            47725           52418
# 1        9997               9997        9997            69117           74110
# 2        9997               9997        9997            47121           52132
# 3        9997               9997        9997            45412           50415
# 4        9997               9997        9997            47831           52493
#
#    Distritos SP  Qtd Vínculos CLT  Qtd Vínculos Ativos  \
# 0          9997                 4                    4
# 1          9997                 1                    1
# 2          9997                 3                    3
# 3          9997                 7                    7
# 4          9997                 4                    4
#
#    Qtd Vínculos Estatutários  Ind Atividade Ano  ...  Município  \
# 0                          0                  1  ...     110028
# ...

# %%
df_rais.columns
# Out:
# Index(['Bairros SP', 'Bairros Fortaleza', 'Bairros RJ', 'CNAE 2.0 Classe',
#        'CNAE 95 Classe', 'Distritos SP', 'Qtd Vínculos CLT',
#        'Qtd Vínculos Ativos', 'Qtd Vínculos Estatutários', 'Ind Atividade Ano',
#        'Ind CEI Vinculado', 'Ind Estab Participa PAT', 'Ind Rais Negativa',
#        'Ind Simples', 'Município', 'Natureza Jurídica', 'Regiões Adm DF',
#        'CNAE 2.0 Subclasse', 'Tamanho Estabelecimento', 'Tipo Estab',
#        'Tipo Estab.1', 'UF', 'IBGE Subsetor', 'CEP Estab'],
#       dtype='object')

# %%
df_rais.loc[0]
# Out:
# Bairros SP                                   9997
# Bairros Fortaleza                            9997
# Bairros RJ                                   9997
# CNAE 2.0 Classe                             47725
# CNAE 95 Classe                              52418
# Distritos SP                                 9997
# Qtd Vínculos CLT                                4
# Qtd Vínculos Ativos                             4
# Qtd Vínculos Estatutários                       0
# Ind Atividade Ano                               1
# Ind CEI Vinculado                               0
# Ind Estab Participa PAT                         9
# Ind Rais Negativa                               0
# Ind Simples                                     0
# Município                                  110028
# Natureza Jurídica                            2062
# Regiões Adm DF                               9997
# CNAE 2.0 Subclasse                        4772500
# Tamanho Estabelecimento                         2
# ...

# %%
import pandas as pd

# %%
df_historico = pd.read_csv('../previsao_contratacao/data/historico_cgu/terceirizados-2010-2023.csv', sep=';', low_memory=False)

# %%
df_historico.head()
# Out:
#    id_terc sg_orgao_sup_tabela_ug  cd_ug_gestora  \
# 0        1                    MDA         490011
# 1        2                    MDA         490011
# 2        3                    MDA         490011
# 3        4                    MDA         490011
# 4        5                    MDA         490011
#
#                                      nm_ug_tabela_ug    sg_ug_gestora  \
# 0  MINISTERIO DO DESENVOLVIMENTO AGRARIO – ADMINI...  MDA-ADM. DIRETA
# 1  MINISTERIO DO DESENVOLVIMENTO AGRARIO – ADMINI...  MDA-ADM. DIRETA
# 2  MINISTERIO DO DESENVOLVIMENTO AGRARIO – ADMINI...  MDA-ADM. DIRETA
# 3  MINISTERIO DO DESENVOLVIMENTO AGRARIO – ADMINI...  MDA-ADM. DIRETA
# 4  MINISTERIO DO DESENVOLVIMENTO AGRARIO – ADMINI...  MDA-ADM. DIRETA
#
#   nr_contrato       nr_cnpj   nm_razao_social          nr_cpf  \
# 0     68/2008  2.633573e+12  AJ SERVICOS LTDA  ***.140.291-**
# 1     68/2008  2.633573e+12  AJ SERVICOS LTDA  ***.338.161-**
# ...

# %%
df_historico.columns
# Out:
# Index(['id_terc', 'sg_orgao_sup_tabela_ug', 'cd_ug_gestora', 'nm_ug_tabela_ug',
#        'sg_ug_gestora', 'nr_contrato', 'nr_cnpj', 'nm_razao_social', 'nr_cpf',
#        'nm_terceirizado', 'nm_categoria_profissional', 'nm_escolaridade',
#        'nr_jornada', 'nm_unidade_prestacao', 'vl_mensal_salario',
#        'vl_mensal_custo', 'Num_Mes_Carga', 'Mes_Carga', 'Ano_Carga',
#        'sg_orgao', 'nm_orgao', 'cd_orgao_siafi', 'cd_orgao_siape'],
#       dtype='object')

# %%
df_historico.shape
# Out:
# (1890255, 23)

# %%
df_historico['nm_categoria_profissional']
# Out:
# 0                                       DIGITADOR
# 1                                       DIGITADOR
# 2                                    SECRETARIO I
# 3                                    SECRETARIO I
# 4                                    SECRETARIO I
#                             ...
# 1890250          422105 - RECEPCIONISTA, EM GERAL
# 1890251          422105 - RECEPCIONISTA, EM GERAL
# 1890252    782305 - MOTORISTA DE CARRO DE PASSEIO
# 1890253                        514320 - FAXINEIRO
# 1890254            517410 - PORTEIRO DE EDIFICIOS
# Name: nm_categoria_profissional, Length: 1890255, dtype: object

# %%
df_historico['nm_orgao'].unique()
# Out:
# array(['MINISTERIO DO DESENVOLVIMENTO AGRARIO',
#        'MINISTERIO DO DESENV. SOCIAL E COMBATE A FOME',
#        'SPOA/MDS E COMBATE A FOME',
#        'FUNDO NACIONAL DA ASSISTENCIA SOCIAL',
#        'SECRETARIA DE PLANEJ.,ORCAM.E ADM.±SPOA/ME',
#        'SUBSECRETARIA DE ASSUNTOS ADMINISTRATIVOS-SAA',
#        'SUBSECRET.DE PLANEJ.,ORCAMENTO E ADM. ± SPOA',
#        'DEPARTAMENTO DE GESTAO INTERNA/MI', 'AGENCIA NACIONAL DO CINEMA',
#        'FUNDACAO BIBLIOTECA NACIONAL', 'FUNDACAO CULTURAL PALMARES',
#        'FUNDACAO CASA DE RUI BARBOSA', 'FUNDACAO NACIONAL DE ARTES',
#        'INSTITUTO DO PATRIMONIO HIST. E ART. NACIONAL',
#        'DIRETORIA DE GESTAO INTERNA/MINC', 'AGENCIA NACIONAL DE AGUAS',
#        'SUBSECRETARIA DE PLANEJ.,ORCAM.E ADM./MMA',
#        'DEPARTAMENTO NACIONAL DE PRODUCAO MINERAL', '<N/I>',
#        'FUND.INST.BRASILEIRO DE GEOG.E ESTATISTICA',
#        'SUBSECRETARIA DE PLANEJ.,ORCAMENTO E ADM./MP',
#        'AGENCIA NACIONAL DE SAUDE SUPLEMENTAR',
# ...

# %%
df_historico['cd_orgao_siafi'].unique()
# Out:
# array(['49000', '55000', '55801', '55001', '51801', '26802', '25804',
#        '53801', '20203', '20404', '20408', '20403', '20412', '20411',
#        '42801', '44205', '44801', '32263', '<N/I>', '25205', '20802',
#        '36213', '39250', '29201', '39801', '20604', '54801', '22201',
#        '20202', '58000', '20125', '30203', '28801', '30204', '20603',
#        '42207', '44206', '32801', '41801', '56801', '20402', '24000',
#        '20301', '20501', '20502', '24801', '24802', '37202', '20701',
#        '26260', '26258', '26241', '20803', '44207', '39252', '38901',
#        '26427', '26409', '25000', '26000', '26283', '36201', '33801',
#        '26237', '26435', '22204', '36000', '44000', '26232', '26244',
#        '26290', '26424', '26234', '32205', '26236', '26421', '41231',
#        '26351', '26431', '32210', '26274', '38000', '26231', '26201',
#        '26406', '26230', '26292', '26251', '26291', '26276', '26411',
# ...

# %%
df_historico[df_historico['cd_orgao_siafi'] == '-2']
# Out:
#          id_terc sg_orgao_sup_tabela_ug  cd_ug_gestora  \
# 1039456  6082945                    MEC         155341
# 1048219  6091772                    MEC         155341
# 1071744  6115502                     MT         393033
# 1076132  6119930                     MT         393033
# 1078998  6122812                    MEC         155341
# ...          ...                    ...            ...
# 1526458  6572033                  MTPAC         390082
# 1526512  6572087                  MTPAC         390082
# 1526535  6572110                   MDSA         550025
# 1526634  6572209                  MTPAC         390082
# 1527334  6572909                  MTPAC         390082
#
#                                            nm_ug_tabela_ug sg_ug_gestora  \
# 1039456  INSTITUTO FEDERAL DE EDUCACAO, CIENCIA E TECNO...           NaN
# 1048219  INSTITUTO FEDERAL DE EDUCACAO, CIENCIA E TECNO...           NaN
# 1071744      SUPERINTENDENCIA REGIONAL NO ESTADO DO PARANA           NaN
# ...

# %%
df_historico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890255 entries, 0 to 1890254
# Data columns (total 23 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   id_terc                    int64
#  1   sg_orgao_sup_tabela_ug     object
#  2   cd_ug_gestora              int64
#  3   nm_ug_tabela_ug            object
#  4   sg_ug_gestora              object
#  5   nr_contrato                object
#  6   nr_cnpj                    float64
#  7   nm_razao_social            object
#  8   nr_cpf                     object
#  9   nm_terceirizado            object
#  10  nm_categoria_profissional  object
#  11  nm_escolaridade            object
#  12  nr_jornada                 object
#  13  nm_unidade_prestacao       object
#  14  vl_mensal_salario          float64
#  15  vl_mensal_custo            float64
#  16  Num_Mes_Carga              float64
#  17  Mes_Carga                  object
#  18  Ano_Carga                  float64
# ...

# %%
import pandas as pd

# %%
df_caged = pd.read_csv("../data/CAGEDMOV202412.txt", sep=";", encoding="utf-8")

# %%
df_caged.head()
# Out:
#    competênciamov  região  uf  município seção  subclasse  saldomovimentação  \
# 0          202412       3  32     320130     N    8129000                  1
# 1          202412       3  33     330455     M    7112000                  1
# 2          202412       3  33     330170     C    1220401                 -1
# 3          202412       3  35     354520     G    4753900                 -1
# 4          202412       4  41     410640     N    8121400                  1
#
#    cbo2002ocupação  categoria  graudeinstrução  ...  indtrabintermitente  \
# 0           783225        101                5  ...                    0
# 1           312105        101                7  ...                    0
# 2           514320        101                5  ...                    0
# 3           414110        101                5  ...                    0
# 4           514320        101                7  ...                    0
#
# ...

# %%
df_caged.columns
# Out:
# Index(['competênciamov', 'região', 'uf', 'município', 'seção', 'subclasse',
#        'saldomovimentação', 'cbo2002ocupação', 'categoria', 'graudeinstrução',
#        'idade', 'horascontratuais', 'raçacor', 'sexo', 'tipoempregador',
#        'tipoestabelecimento', 'tipomovimentação', 'tipodedeficiência',
#        'indtrabintermitente', 'indtrabparcial', 'salário', 'tamestabjan',
#        'indicadoraprendiz', 'origemdainformação', 'competênciadec',
#        'indicadordeforadoprazo', 'unidadesaláriocódigo', 'valorsaláriofixo'],
#       dtype='object')

# %%
df_caged['tipoempregador']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 3584044    0
# 3584045    0
# 3584046    0
# 3584047    0
# 3584048    0
# Name: tipoempregador, Length: 3584049, dtype: int64

# %%
df_caged['tipoestabelecimento']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 3584044    1
# 3584045    1
# 3584046    1
# 3584047    1
# 3584048    1
# Name: tipoestabelecimento, Length: 3584049, dtype: int64

# %%
df_caged['tipomovimentação']
# Out:
# 0          97
# 1          97
# 2          31
# 3          31
# 4          97
#            ..
# 3584044    60
# 3584045    97
# 3584046    43
# 3584047    32
# 3584048    97
# Name: tipomovimentação, Length: 3584049, dtype: int64

# %%
df_dic = pd.read_csv('../data/br_me_caged_dicionario.csv', sep=',')

# %%
df_dic[df_dic['nome_coluna'] == 'tipo_movimentacao']
# Out:
#                     id_tabela        nome_coluna  chave cobertura_temporal  \
# 4958  microdados_movimentacao  tipo_movimentacao     33        2020(1)2021
# 4959  microdados_movimentacao  tipo_movimentacao     99        2020(1)2021
# 4960  microdados_movimentacao  tipo_movimentacao     40        2020(1)2021
# 4961  microdados_movimentacao  tipo_movimentacao     60        2020(1)2021
# 4962  microdados_movimentacao  tipo_movimentacao     20        2020(1)2021
# 4963  microdados_movimentacao  tipo_movimentacao     35        2020(1)2021
# 4964  microdados_movimentacao  tipo_movimentacao     70        2020(1)2021
# 4965  microdados_movimentacao  tipo_movimentacao     98        2020(1)2021
# 4966  microdados_movimentacao  tipo_movimentacao     10        2020(1)2021
# 4967  microdados_movimentacao  tipo_movimentacao     50        2020(1)2021
# 4968  microdados_movimentacao  tipo_movimentacao     80        2020(1)2021
# ...
